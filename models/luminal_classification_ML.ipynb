# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../utils/')

from radiomics_helper import *

# %%
#Declaring constants

# %%
img_dir = '../data/mass_data/AIIMS_Delhi_Mass_Data/subtype_classification/images/'
mask_dir = '../data/mass_data/AIIMS_Delhi_Mass_Data/subtype_classification/masks/'
